# %%
import numpy as np
import os
import trimesh
from trimesh.sample import sample_surface_sphere
from trimesh.ray.ray_pyembree import RayMeshIntersector
from shapely.geometry import LineString
from matplotlib import pyplot as plt
from tqdm import tqdm_notebook as tqdm
from open3d import *
# %matplotlib inline

# %%
DATA_DIR = '../../../../data/ShapeNetCorev2/ShapeNetCore.v2/'

# %%
for synsetId in tqdm(os.listdir(DATA_DIR)):
    SYNSET_DIR = os.path.join(DATA_DIR, synsetId)
    for modelId in os.listdir(SYNSET_DIR):
        mesh = trimesh.load(os.path.join(SYNSET_DIR, modelId, 'models', 'model_normalized.obj'))
        if mesh.is_watertight:
            print(1)
# Out:
# HBox(children=(IntProgress(value=0, max=56), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-22dca533d776> in <module>()
#       2     SYNSET_DIR = os.path.join(DATA_DIR, synsetId)
#       3     for modelId in os.listdir(SYNSET_DIR):
# ----> 4         mesh = trimesh.load(os.path.join(SYNSET_DIR, modelId, 'models', 'model_normalized.obj'))
#       5         if mesh.is_watertight:
#       6             print(1)
#
# /opt/conda/lib/python3.6/site-packages/trimesh/exchange/load.py in load(file_obj, file_type, resolver, **kwargs)
#     116      ) = parse_file_args(file_obj=file_obj,
#     117                          file_type=file_type,
# --> 118                          resolver=resolver)
#     119
#     120     try:
#
# /opt/conda/lib/python3.6/site-packages/trimesh/exchange/load.py in parse_file_args(file_obj, file_type, resolver, **kwargs)
#     534                     'use load_remote to load URL: {}'.format(file_obj))
#     535             elif file_type is None:
# --> 536                 raise ValueError('string is not a file: {}'.format(file_obj))
#     537
#     538     if file_type is None:
#
# ValueError: string is not a file: ../../../../data/ShapeNetCorev2/ShapeNetCore.v2/02958343/302612708e86efea62d2c237bfbc22ca/models/model_normalized.obj
